# %% [markdown]
# <p>BELLEL OUSSAMA : 21817080</p>
# <p>BOURGIN Jérémy : 20140477</p>
# <p>DIABATE Amara : 21509428</p>
# <p>HERRI Abdallah : 21712664</p>

# %% [markdown]
# <h1>Initialisation des données</h1>

# %%
import pandas as pd
import sys
import re

sys.path.insert(0, "../lib")

import os

import nltk
from nltk import ngrams
from nltk.util import everygrams
from nltk.parse import CoreNLPParser
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import pickle

os.environ["NLTK_DATA"] = "../"
nltk.data.path.append("../nltk_data")

pos_tagger = CoreNLPParser(url='http://localhost:9000', tagtype='pos')

# %% [markdown]
# <h1>Import et association des données</h1>

# %%
df_set = pd.read_csv('../data/dataset.csv',sep="\t", header=None, encoding="utf8")
df_set = df_set.rename(index = int, columns = {0: "comment"})
#display(df1)

df_labels = pd.read_csv('../data/labels.csv',sep="\t", header=None, encoding="utf8")
df_labels = df_labels.rename(index = int, columns = {0: "result"})
#display(df2)

df_raw = pd.concat([df_set, df_labels], axis=1)

df_raw
# Out:
#                                                 comment  result
# 0     Obviously made to show famous 1950s stripper M...      -1
# 1     This film was more effective in persuading me ...      -1
# 2     Unless you are already familiar with the pop s...      -1
# 3     From around the time Europe began fighting Wor...      -1
# 4     Im not surprised that even cowgirls get the bl...      -1
# 5     (48 out of 278 people found this comment usefu...      -1
# 6     Went to watch this movie expecting a 'nothing ...      -1
# 7     A good cast and they do their best with what t...      -1
# 8     The only thing that kept me from vomiting afte...      -1
# 9     I just watched this film 15 minutes ago, and I...      -1
# 10    There are two reasons why I did not give a 1 t...      -1
# 11    The Man In The Attic is a movie set in the 191...      -1
# 12    During a sleepless night, I was switching thro...      -1
# 13    No,Basically your watching something that does...      -1
# 14    I am dumbfounded that I actually sat and watch...      -1
# 15    In an otherwise good review, loleralacartelort...      -1
# 16    This version of "Moby Dick" insults the audien...      -1
# 17    In a summer that also boasted such repugnant s...      -1
# 18    The dudes at MST3K should see this dog of a fi...      -1
# 19    A mediocre Sci-Fi Channel original picture. A ...      -1
# 20    I went to see this movie with a crowd that con...      -1
# 21    Its hard to make heads or tails of this film. ...      -1
# 22    One of those classics, held up next to "Deep T...      -1
# 23    Joe Don Baker. He was great in "Walking Tall" ...      -1
# 24    I waited for this movie to play in great antic...      -1
# 25    Such a long awaited movie.. But it has disappo...      -1
# 26    five minutes after watching this i logged on t...      -1
# 27    i can't figure out who greenlighted this thing...      -1
# 28    The most ridiculous thing about this ridiculou...      -1
# 29    Seriously, I absolutely love these old movies ...      -1
# ...                                                 ...     ...
# 9970  Garde  Vue has to be seen a number of times in...       1
# 9971  Chances are, you'll think this movie is incred...       1
# 9972  Doctor Mordrid is one of those rare films that...       1
# 9973  Pop quiz: you're a part of the modern armed fo...       1
# 9974  I found this film to be a fascinating study of...       1
# 9975  All the folks who sit here and say that this m...       1
# 9976  There were some great moments of reality in th...       1
# 9977  The anime that got me hooked on anime...Set in...       1
# 9978  This movie is cold, bare truth. Often we think...       1
# 9979  Fifteen years later and Paris Is Burning is st...       1
# 9980  In one of her first movies, Romy Schneider shi...       1
# 9981  Cinderella is one of the most beloved of all D...       1
# 9982  Twelve Monkeys is odd and disturbing, yet bein...       1
# 9983  When it comes to movies I can be pretty picky,...       1
# 9984  It wasn't me! It was, er, my twin brother Rupe...       1
# 9985  I don't hand out ten star ratings easily. A mo...       1
# 9986  Yes, it's over the top, yes it's a bit clichd ...       1
# 9987  If you have any sort of appreciation for chara...       1
# 9988  I have seen a lot of Saura films and always fo...       1
# 9989  Those French and those Germans sure have a lon...       1
# 9990  please, future writers, producers, directors -...       1
# 9991  Dan Katzir has produced a wonderful film that ...       1
# 9992  This is perhaps the best rockumentary ever- a ...       1
# 9993  This is one powerful film. The first time I sa...       1
# 9994  Myself and my groovadelic 20-something pals ju...       1
# 9995  Finally, an indie film that actually delivers ...       1
# 9996  House of Games is a wonderful movie at multipl...       1
# 9997  The movie was excellent, save for some of the ...       1
# 9998  Spin it!The 90s opened up with a clever Disney...       1
# 9999  I keep watching this movie over and over and o...       1
#
# [10000 rows x 2 columns]

# %% [markdown]
# <h1>Pré-traitement</h1>

# %% [markdown]
# <h2>Nettoyage du texte</h2>
# <ul>
#     <li>Supression des liens</li>
#     <li>Supression des adresses mails</li>
#     <li>Supression des doubles quotes (NLTK va considérer "word" et word comme 2 mots distinct)</li>
#     <li>Ajout d'un espace avant et après chaque ponctuation (si quelqu'un fait une faute de frappe et écrit (word1.word2 NLTK va considérer cela comme un seul mot)</li>
#     <li>Supression des simple quote inutile</li>
# </ul>

# %%
def clean_text(text):
    replace_chars = [
        [r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', "", True],
        [r'[\w\.-]+@[\w\.-]+', "", True],
        ["\"", "", False],
        ["|", " ", False],
        [".", " . ", False],
        [",", " , ", False],
        [";", " ; ", False],
        ["?", " ? ", False],
        [":", " : ", False],
        ["!", " ! ", False],
        ["``", "", False],
        ["`", "'", False],
        [" '", " ", False],
        ["' ", " ", False]
    ]

    for e in replace_chars:
        if (e[2]):
            text = re.sub(e[0], e[1], text, flags=re.MULTILINE)
        else:
            text = text.replace(e[0], e[1])

    return text

# %% [markdown]
# <h2>Tokeniser du texte avec NLTK</h2>

# %%
def text_to_token(text):
    tokens = nltk.word_tokenize(text)
    
    return tokens

# %% [markdown]
# <p>détokenizer</p>

# %%
def token_to_text(tokens, delete_words = [], rename_words = {}, concat_words = []):    
    r = ""
    rename_words_keys = rename_words.keys()
    
    for w in tokens:
        if (w in delete_words):
            continue
        
        if (w in rename_words_keys):
            w = rename_words[w]
        
        r += w
        
        if (w in concat_words):
            r += "|"
        else:
            r += " "
    
    return r

# %% [markdown]
# <h2>Filtrage des tokens</h2>
# <p>Les adjectifs permette de qualifier différentes choses dans une phrase. C'est pourquoi, nous gardons seulement les adjectifs.</p>

# %%
def filter_tags(tokens, ls):
    temp_tokens = []
    
    for e in tokens:
        o = e.split("|")
        e = o[-1]
        
        if (len(e) == 0):
            e = o[0]
        
        temp_tokens.append(e)
        
    #old way : NLTK
    tags = nltk.pos_tag(temp_tokens)
    
    #new way : stanford
    #tags = pos_tagger.tag(temp_tokens)
    
    r = []
    
    for i in range(0, len(tags)):
        e = tags[i]
        
        for t in ls:
            if e[1] == t:
                w = tokens[i].replace("|", "")
                r.append(w)
        
    return r

# %% [markdown]
# <h2>NLTK : n-grams, every-grams, and Stop-Word</h2>

# %% [markdown]
# <p>Test</p>
# <p>Conclusion du test : n-grams et every-grams sont tous les deux intéressants. Cependant, il est encore difficile de les départager (on pense quand même que every-grams sera meilleur, car il sera peut être plus adapté sur d'autre jeu de données alors que n-grams sera peut être meilleur sur le jeu de données initial mais moins bon sur d'autres. On notera que l'utilisation de ces 2 algorithmes nécessite l'utilisation des stop-word pour avoir des associations de mots plus intéressants.</p>

# %%
text = "N-GRAMS and EVERYGRAMS are pretty good, but I don't know which will be better. This exemple is not so good. I'm into bad."
tokens = nltk.word_tokenize(text)

n = 4
twograms = list(ngrams(tokens, n))
twoeverygrams = list(everygrams(tokens, max_len=n))

stopWords = set(stopwords.words('english'))
tokens_word = word_tokenize(text)

tokens_filtered = []
text_filtered = ""

for w in tokens_word:
    if (w == "n't"):
        w = "not"
    
    if (w == "not") or (w not in stopWords):
        tokens_filtered.append(w)
        text_filtered += w + " "

twogramsstopword = list(ngrams(tokens_filtered, n))
twoeverygramsstopword = list(everygrams(tokens_filtered, max_len=n))

print("----------------------------------------------")

print ("original text : ")
print(text)

print ("stop word : ")
print(text_filtered)

print("----------------------------------------------")

print("TWO GRAMS")
display (twograms)
print("EVERY GRAMS")
display (twoeverygrams)

print("----------------------------------------------")

print("TWO GRAMS + stop words")
display (twogramsstopword)
print("EVERY GRAMS + stop words")
display (twoeverygramsstopword)

print("----------------------------------------------")
# Out:
# ----------------------------------------------
# original text :
# N-GRAMS and EVERYGRAMS are pretty good, but I don't know which will be better. This exemple is not so good. I'm into bad.
# stop word :
# N-GRAMS EVERYGRAMS pretty good , I not know better . This exemple not good . I 'm bad .
# ----------------------------------------------
# TWO GRAMS
# [('N-GRAMS', 'and', 'EVERYGRAMS', 'are'),
#  ('and', 'EVERYGRAMS', 'are', 'pretty'),
#  ('EVERYGRAMS', 'are', 'pretty', 'good'),
#  ('are', 'pretty', 'good', ','),
#  ('pretty', 'good', ',', 'but'),
#  ('good', ',', 'but', 'I'),
#  (',', 'but', 'I', 'do'),
#  ('but', 'I', 'do', "n't"),
#  ('I', 'do', "n't", 'know'),
#  ('do', "n't", 'know', 'which'),
#  ("n't", 'know', 'which', 'will'),
#  ('know', 'which', 'will', 'be'),
#  ('which', 'will', 'be', 'better'),
#  ('will', 'be', 'better', '.'),
#  ('be', 'better', '.', 'This'),
#  ('better', '.', 'This', 'exemple'),
#  ('.', 'This', 'exemple', 'is'),
#  ('This', 'exemple', 'is', 'not'),
#  ('exemple', 'is', 'not', 'so'),
#  ('is', 'not', 'so', 'good'),
#  ('not', 'so', 'good', '.'),
#  ('so', 'good', '.', 'I'),
#  ('good', '.', 'I', "'m"),
#  ('.', 'I', "'m", 'into'),
#  ('I', "'m", 'into', 'bad'),
#  ("'m", 'into', 'bad', '.')]
# EVERY GRAMS
# [('N-GRAMS',),
#  ('and',),
#  ('EVERYGRAMS',),
#  ('are',),
#  ('pretty',),
#  ('good',),
#  (',',),
#  ('but',),
#  ('I',),
#  ('do',),
#  ("n't",),
#  ('know',),
#  ('which',),
#  ('will',),
#  ('be',),
#  ('better',),
#  ('.',),
#  ('This',),
#  ('exemple',),
#  ('is',),
#  ('not',),
#  ('so',),
#  ('good',),
#  ('.',),
#  ('I',),
#  ("'m",),
#  ('into',),
#  ('bad',),
#  ('.',),
#  ('N-GRAMS', 'and'),
#  ('and', 'EVERYGRAMS'),
#  ('EVERYGRAMS', 'are'),
#  ('are', 'pretty'),
#  ('pretty', 'good'),
#  ('good', ','),
#  (',', 'but'),
#  ('but', 'I'),
#  ('I', 'do'),
#  ('do', "n't"),
#  ("n't", 'know'),
#  ('know', 'which'),
#  ('which', 'will'),
#  ('will', 'be'),
#  ('be', 'better'),
#  ('better', '.'),
#  ('.', 'This'),
#  ('This', 'exemple'),
#  ('exemple', 'is'),
#  ('is', 'not'),
#  ('not', 'so'),
#  ('so', 'good'),
#  ('good', '.'),
#  ('.', 'I'),
#  ('I', "'m"),
#  ("'m", 'into'),
#  ('into', 'bad'),
#  ('bad', '.'),
#  ('N-GRAMS', 'and', 'EVERYGRAMS'),
#  ('and', 'EVERYGRAMS', 'are'),
#  ('EVERYGRAMS', 'are', 'pretty'),
#  ('are', 'pretty', 'good'),
#  ('pretty', 'good', ','),
#  ('good', ',', 'but'),
#  (',', 'but', 'I'),
#  ('but', 'I', 'do'),
#  ('I', 'do', "n't"),
#  ('do', "n't", 'know'),
#  ("n't", 'know', 'which'),
#  ('know', 'which', 'will'),
#  ('which', 'will', 'be'),
#  ('will', 'be', 'better'),
#  ('be', 'better', '.'),
#  ('better', '.', 'This'),
#  ('.', 'This', 'exemple'),
#  ('This', 'exemple', 'is'),
#  ('exemple', 'is', 'not'),
#  ('is', 'not', 'so'),
#  ('not', 'so', 'good'),
#  ('so', 'good', '.'),
#  ('good', '.', 'I'),
#  ('.', 'I', "'m"),
#  ('I', "'m", 'into'),
#  ("'m", 'into', 'bad'),
#  ('into', 'bad', '.'),
#  ('N-GRAMS', 'and', 'EVERYGRAMS', 'are'),
#  ('and', 'EVERYGRAMS', 'are', 'pretty'),
#  ('EVERYGRAMS', 'are', 'pretty', 'good'),
#  ('are', 'pretty', 'good', ','),
#  ('pretty', 'good', ',', 'but'),
#  ('good', ',', 'but', 'I'),
#  (',', 'but', 'I', 'do'),
#  ('but', 'I', 'do', "n't"),
#  ('I', 'do', "n't", 'know'),
#  ('do', "n't", 'know', 'which'),
#  ("n't", 'know', 'which', 'will'),
#  ('know', 'which', 'will', 'be'),
#  ('which', 'will', 'be', 'better'),
#  ('will', 'be', 'better', '.'),
#  ('be', 'better', '.', 'This'),
#  ('better', '.', 'This', 'exemple'),
#  ('.', 'This', 'exemple', 'is'),
#  ('This', 'exemple', 'is', 'not'),
#  ('exemple', 'is', 'not', 'so'),
#  ('is', 'not', 'so', 'good'),
#  ('not', 'so', 'good', '.'),
#  ('so', 'good', '.', 'I'),
#  ('good', '.', 'I', "'m"),
#  ('.', 'I', "'m", 'into'),
#  ('I', "'m", 'into', 'bad'),
#  ("'m", 'into', 'bad', '.')]
# ----------------------------------------------
# TWO GRAMS + stop words
# [('N-GRAMS', 'EVERYGRAMS', 'pretty', 'good'),
#  ('EVERYGRAMS', 'pretty', 'good', ','),
#  ('pretty', 'good', ',', 'I'),
#  ('good', ',', 'I', 'not'),
#  (',', 'I', 'not', 'know'),
#  ('I', 'not', 'know', 'better'),
#  ('not', 'know', 'better', '.'),
#  ('know', 'better', '.', 'This'),
#  ('better', '.', 'This', 'exemple'),
#  ('.', 'This', 'exemple', 'not'),
#  ('This', 'exemple', 'not', 'good'),
#  ('exemple', 'not', 'good', '.'),
#  ('not', 'good', '.', 'I'),
#  ('good', '.', 'I', "'m"),
#  ('.', 'I', "'m", 'bad'),
#  ('I', "'m", 'bad', '.')]
# EVERY GRAMS + stop words
# [('N-GRAMS',),
#  ('EVERYGRAMS',),
#  ('pretty',),
#  ('good',),
#  (',',),
#  ('I',),
#  ('not',),
#  ('know',),
#  ('better',),
#  ('.',),
#  ('This',),
#  ('exemple',),
#  ('not',),
#  ('good',),
#  ('.',),
#  ('I',),
#  ("'m",),
#  ('bad',),
#  ('.',),
#  ('N-GRAMS', 'EVERYGRAMS'),
#  ('EVERYGRAMS', 'pretty'),
#  ('pretty', 'good'),
#  ('good', ','),
#  (',', 'I'),
#  ('I', 'not'),
#  ('not', 'know'),
#  ('know', 'better'),
#  ('better', '.'),
#  ('.', 'This'),
#  ('This', 'exemple'),
#  ('exemple', 'not'),
#  ('not', 'good'),
#  ('good', '.'),
#  ('.', 'I'),
#  ('I', "'m"),
#  ("'m", 'bad'),
#  ('bad', '.'),
#  ('N-GRAMS', 'EVERYGRAMS', 'pretty'),
#  ('EVERYGRAMS', 'pretty', 'good'),
#  ('pretty', 'good', ','),
#  ('good', ',', 'I'),
#  (',', 'I', 'not'),
#  ('I', 'not', 'know'),
#  ('not', 'know', 'better'),
#  ('know', 'better', '.'),
#  ('better', '.', 'This'),
#  ('.', 'This', 'exemple'),
#  ('This', 'exemple', 'not'),
#  ('exemple', 'not', 'good'),
#  ('not', 'good', '.'),
#  ('good', '.', 'I'),
#  ('.', 'I', "'m"),
#  ('I', "'m", 'bad'),
#  ("'m", 'bad', '.'),
#  ('N-GRAMS', 'EVERYGRAMS', 'pretty', 'good'),
#  ('EVERYGRAMS', 'pretty', 'good', ','),
#  ('pretty', 'good', ',', 'I'),
#  ('good', ',', 'I', 'not'),
#  (',', 'I', 'not', 'know'),
#  ('I', 'not', 'know', 'better'),
#  ('not', 'know', 'better', '.'),
#  ('know', 'better', '.', 'This'),
#  ('better', '.', 'This', 'exemple'),
#  ('.', 'This', 'exemple', 'not'),
#  ('This', 'exemple', 'not', 'good'),
#  ('exemple', 'not', 'good', '.'),
#  ('not', 'good', '.', 'I'),
#  ('good', '.', 'I', "'m"),
#  ('.', 'I', "'m", 'bad'),
#  ('I', "'m", 'bad', '.')]
# ----------------------------------------------

# %% [markdown]
# <h1>Stop word + détection négation</h1>

# %%
def clean_and_negation(text):
    tokens = word_tokenize(text)
    stopWords = set(stopwords.words('english'))
    stopWords.remove('not') 
    
    r = token_to_text(
        tokens,
        delete_words=stopWords,
        rename_words={"n't": "not"},
        concat_words=["not"]
    )
    
    return r

# %% [markdown]
# <h1>Fonction de pré-traitement</h1>

# %%
def pre_traitement(text):
    text = clean_text(text)
    text = clean_and_negation(text)
    tokens = text_to_token(text)
    r = filter_tags(tokens, ["JJ", "JJR", "JJS", "RBR", "RBS"])
    
    return r

# %% [markdown]
# <p>exemple pre-traitement</p>

# %%
exemple = df_raw["comment"][4]
filtered_tags = pre_traitement(exemple)

exemple2 = "this is not good"
filtered_tags2 = pre_traitement(exemple2)

display(filtered_tags)
display(filtered_tags2)
# Out:
# ['cowgirls', 'better', 'awful', 'incapable']
# ['notgood']

# %% [markdown]
# <h1>Différentes fonctions</h1>

# %% [markdown]
# <p>Fonction pour appliquer un algorithme</p>

# %%
def apply_algo(algo_avis_fun, algo_sarcasme_fun, text):
    result_avis = algo_avis_fun(text)
    result_sarcasme = algo_sarcasme_fun(text)
    
    if (result_sarcasme):
        return -result_avis
    else:
        return result_avis

# %% [markdown]
# <p>Fonction pour tester le taux de réussite d'un algorithme</p>

# %%
def test_algo(algo_avis_fun, algo_sarcasme_fun, df):
    size = df.shape[0]
    coef = 0
    acc = []

    for i in range(0, size):
        filtered_tags = df["filtered_tags"][i]
        algo_result = apply_algo(algo_avis_fun, algo_sarcasme_fun, filtered_tags)
        acc.append(algo_result)
        
    accuracy = accuracy_score(df["result"], acc)
    report = classification_report(df["result"], acc)
    confusion = confusion_matrix(df["result"], acc)
    r = {"accuracy": accuracy, "report": report, "confusion": confusion}
    
    return r

# %% [markdown]
# <p>Algorithme de sarcasme par défaut (uniquement pour faire des tests tant que l'on a pas d'algorithme pour détecter le sarcasme)</p>

# %%
def dumb_sarcasme(text):
    return False

# %% [markdown]
# <h1>Fonction de pré-traitement</h1>
# <p>Fonction permettant de créer un nouveau classifieur avec tous les pré-traitements appliqué</p>

# %%
def parse_df(df):
    size = df.shape[0]
    
    data = {
        "filtered_tags": [],
        "text_filtered_tags": [],
        "clean_comment": [],
        "neg_comment": []
    }
    
    for i in range(0, size):
        text = df["comment"][i]
        text_cleaned = clean_text(text)
        text_neg = clean_and_negation(text_cleaned).replace("|", "")
        filtered_tags = pre_traitement(text)
        text_filtered_tags = token_to_text(filtered_tags)
        
        data["filtered_tags"].append(filtered_tags)
        data["text_filtered_tags"].append(text_filtered_tags)
        data["clean_comment"].append(text_cleaned)
        data["neg_comment"].append(text_neg)
    
    df_temp = pd.DataFrame(data)
    df_result = pd.concat([df, df_temp], axis=1)
    
    return df_result

# %%
clean_df = parse_df(df_raw)

clean_df
# Out:
#                                                 comment  result  \
# 0     Obviously made to show famous 1950s stripper M...      -1
# 1     This film was more effective in persuading me ...      -1
# 2     Unless you are already familiar with the pop s...      -1
# 3     From around the time Europe began fighting Wor...      -1
# 4     Im not surprised that even cowgirls get the bl...      -1
# 5     (48 out of 278 people found this comment usefu...      -1
# 6     Went to watch this movie expecting a 'nothing ...      -1
# 7     A good cast and they do their best with what t...      -1
# 8     The only thing that kept me from vomiting afte...      -1
# 9     I just watched this film 15 minutes ago, and I...      -1
# 10    There are two reasons why I did not give a 1 t...      -1
# 11    The Man In The Attic is a movie set in the 191...      -1
# 12    During a sleepless night, I was switching thro...      -1
# 13    No,Basically your watching something that does...      -1
# 14    I am dumbfounded that I actually sat and watch...      -1
# 15    In an otherwise good review, loleralacartelort...      -1
# 16    This version of "Moby Dick" insults the audien...      -1
# 17    In a summer that also boasted such repugnant s...      -1
# 18    The dudes at MST3K should see this dog of a fi...      -1
# 19    A mediocre Sci-Fi Channel original picture. A ...      -1
# 20    I went to see this movie with a crowd that con...      -1
# 21    Its hard to make heads or tails of this film. ...      -1
# 22    One of those classics, held up next to "Deep T...      -1
# 23    Joe Don Baker. He was great in "Walking Tall" ...      -1
# 24    I waited for this movie to play in great antic...      -1
# 25    Such a long awaited movie.. But it has disappo...      -1
# 26    five minutes after watching this i logged on t...      -1
# 27    i can't figure out who greenlighted this thing...      -1
# 28    The most ridiculous thing about this ridiculou...      -1
# 29    Seriously, I absolutely love these old movies ...      -1
# ...                                                 ...     ...
# 9970  Garde  Vue has to be seen a number of times in...       1
# 9971  Chances are, you'll think this movie is incred...       1
# 9972  Doctor Mordrid is one of those rare films that...       1
# 9973  Pop quiz: you're a part of the modern armed fo...       1
# 9974  I found this film to be a fascinating study of...       1
# 9975  All the folks who sit here and say that this m...       1
# 9976  There were some great moments of reality in th...       1
# 9977  The anime that got me hooked on anime...Set in...       1
# 9978  This movie is cold, bare truth. Often we think...       1
# 9979  Fifteen years later and Paris Is Burning is st...       1
# 9980  In one of her first movies, Romy Schneider shi...       1
# 9981  Cinderella is one of the most beloved of all D...       1
# 9982  Twelve Monkeys is odd and disturbing, yet bein...       1
# 9983  When it comes to movies I can be pretty picky,...       1
# 9984  It wasn't me! It was, er, my twin brother Rupe...       1
# 9985  I don't hand out ten star ratings easily. A mo...       1
# 9986  Yes, it's over the top, yes it's a bit clichd ...       1
# 9987  If you have any sort of appreciation for chara...       1
# 9988  I have seen a lot of Saura films and always fo...       1
# 9989  Those French and those Germans sure have a lon...       1
# 9990  please, future writers, producers, directors -...       1
# 9991  Dan Katzir has produced a wonderful film that ...       1
# 9992  This is perhaps the best rockumentary ever- a ...       1
# 9993  This is one powerful film. The first time I sa...       1
# 9994  Myself and my groovadelic 20-something pals ju...       1
# 9995  Finally, an indie film that actually delivers ...       1
# 9996  House of Games is a wonderful movie at multipl...       1
# 9997  The movie was excellent, save for some of the ...       1
# 9998  Spin it!The 90s opened up with a clever Disney...       1
# 9999  I keep watching this movie over and over and o...       1
#
#                                           filtered_tags  \
# 0     [famous, bad, little, tale, innocent, white, l...
# 1     [effective, Jewish, Freshman, alarmist, palata...
# 2     [familiar, stop, next, insist, Japanese, teen,...
# 3     [significant, young, enlist, serviceman, appea...
# 4                  [cowgirls, better, awful, incapable]
# 5     [found, useful, much, hollow, iconic, worse, m...
# 6     [Went, much, disappointed, opening, little, fi...
# 7     [good, best, inexplicable, many, unintentional...
# 8     [main, much, root, abyssmal, bad, worse, poor,...
# 9     [star, realistic, murdered, sister, investigat...
# 10    [good, many, bad, cool, different, else, bad, ...
# 11    [Attic, true, responsible, packaging, best, st...
# 12    [sleepless, embarrassment, pathetic, much, bes...
# 13    [take, normal, everyday, driving, many, accoun...
# 14    [watched, independent, whole, general, great, ...
# 15    [good, secret, notwell-known, exact, secret, s...
# 16    [novel-even, phony, first, famous, atrocious, ...
# 17    [repugnant, pretty, bold, hyper-indulgent, stu...
# 18    [dog, dopey, strange, dumb, naive, acting, hea...
# 19    [mediocre, original, little, squirmish, nuclea...
# 20    [spiritual, much, good, spiritual, least, tole...
# 21              [hard, oiled, unappetizing, notfretful]
# 22         [next, female, notattractive, nothot, Worth]
# 23    [great, Tall, good, dark, main, claws, deep, a...
# 24    [great, many, tiny, new, child, light, underst...
# 25    [Such, awaited, disappointed, bad, professiona...
# 26    [whole, ta, embarrassed, biggest, patrick, sor...
# 27    [greenlighted, bad, bad, bad, bad, bad, bad, l...
# 28    [ridiculous, ridiculous, significant, live, no...
# 29    [old, first, last, bottom, bad, bad, anal, ent...
# ...                                                 ...
# 9970  [sub-plots, french, wordy, boredom, french, ve...
# 9971  [stupid, first, second, third, fourth, fifth, ...
# 9972  [rare, worthwhile, old, Which, follow-up, note...
# 9973  [routine, thrown, Japanese, American, no-one, ...
# 9974  [oldest, strange, demonstrative, likely, young...
# 9975        [weak, ok, kick, bean, wet, white, instant]
# 9976  [great, modern, real, awkwardness, excessivene...
# 9977  [hooked, committed, third, fictional, heroes, ...
# 9978  [big, many, young, exotic, nightmare, sort, no...
# 9979  [classic, black, right, honorary, black, semin...
# 9980  [first, young, queen, throne, govern, faithful...
# 9981  [classic, fairy-tale, good, unlikable, royal, ...
# 9982  [clever, intelligent, future, past, man-made, ...
# 9983  [picky, wrong, low, last, hard, actual, notsex...
# 9984               [best, much, screen, classic, worth]
# 9985  [impress, greatest, notdifferent, powerful, la...
# 9986  [top, clichd, total, worthy, old, repetitive, ...
# 9987  [sort, sense, American, cultural, enough, comp...
# 9988  [amazing, great, cinema, better, contemporary,...
# 9989  [French, sure, long, interesting, nightclub, F...
# 9990  [future, bold, original, big, many, fantasy, n...
# 9991  [wonderful, roller-coaster, ride, real, modern...
# 9992  [best, rockumentary, ever-, British, better, S...
# 9993  [powerful, first, Scottish, tough, English, go...
# 9994  [groovadelic, 20-something, enough, awesome, b...
# 9995  [great, horror, Theatrical, watchable, fewer, ...
# 9996  [wonderful, fine, marvelous, strong, strong, s...
# 9997  [thanks, great, see, human, basic, great, usua...
# 9998  [action-packed, favorite, entire, first, origi...
# 9999  [least, taught, full, teen, mad, busy, old, se...
#
#                                      text_filtered_tags  \
# 0     famous bad little tale innocent white likable ...
# 1     effective Jewish Freshman alarmist palatable p...
# 2     familiar stop next insist Japanese teen idol p...
# 3     significant young enlist serviceman appear slo...
# 4                      cowgirls better awful incapable
# 5     found useful much hollow iconic worse murder-s...
# 6     Went much disappointed opening little first re...
# 7     good best inexplicable many unintentional pier...
# 8         main much root abyssmal bad worse poor first
# 9     star realistic murdered sister investigate loc...
# 10    good many bad cool different else bad useless ...
# 11    Attic true responsible packaging best steamy e...
# 12    sleepless embarrassment pathetic much best ner...
# 13    take normal everyday driving many account grea...
# 14    watched independent whole general great least ...
# 15    good secret notwell-known exact secret secret ...
# 16    novel-even phony first famous atrocious greate...
# 17    repugnant pretty bold hyper-indulgent stuff re...
# 18    dog dopey strange dumb naive acting head many ...
# 19    mediocre original little squirmish nuclear pow...
# 20    spiritual much good spiritual least tolerate a...
# 21                  hard oiled unappetizing notfretful
# 22              next female notattractive nothot Worth
# 23    great Tall good dark main claws deep ample fle...
# 24    great many tiny new child light understand unr...
# 25    Such awaited disappointed bad professional Goo...
# 26    whole ta embarrassed biggest patrick sorry not...
# 27    greenlighted bad bad bad bad bad bad least con...
# 28    ridiculous ridiculous significant live notsign...
# 29    old first last bottom bad bad anal entire nota...
# ...                                                 ...
# 9970  sub-plots french wordy boredom french veil old...
# 9971   stupid first second third fourth fifth spitting
# 9972  rare worthwhile old Which follow-up notenough ...
# 9973  routine thrown Japanese American no-one Japane...
# 9974  oldest strange demonstrative likely youngest d...
# 9975               weak ok kick bean wet white instant
# 9976  great modern real awkwardness excessiveness ho...
# 9977  hooked committed third fictional heroes new re...
# 9978  big many young exotic nightmare sort notimprob...
# 9979  classic black right honorary black seminal und...
# 9980  first young queen throne govern faithful real ...
# 9981  classic fairy-tale good unlikable royal eligib...
# 9982  clever intelligent future past man-made human ...
# 9983  picky wrong low last hard actual notsexual qui...
# 9984                    best much screen classic worth
# 9985  impress greatest notdifferent powerful landmar...
# 9986  top clichd total worthy old repetitive fun ton...
# 9987  sort sense American cultural enough complex wo...
# 9988  amazing great cinema better contemporary impor...
# 9989  French sure long interesting nightclub French ...
# 9990  future bold original big many fantasy new crea...
# 9991  wonderful roller-coaster ride real modern love...
# 9992  best rockumentary ever- British better Spinal ...
# 9993  powerful first Scottish tough English good exc...
# 9994  groovadelic 20-something enough awesome bad su...
# 9995  great horror Theatrical watchable fewer good g...
# 9996  wonderful fine marvelous strong strong sharp h...
# 9997  thanks great see human basic great usual see e...
# 9998  action-packed favorite entire first original g...
# 9999  least taught full teen mad busy old see Africa...
#
#                                           clean_comment  \
# 0     Obviously made to show famous 1950s stripper M...
# 1     This film was more effective in persuading me ...
# 2     Unless you are already familiar with the pop s...
# 3     From around the time Europe began fighting Wor...
# 4     Im not surprised that even cowgirls get the bl...
# 5     (48 out of 278 people found this comment usefu...
# 6     Went to watch this movie expecting a nothing r...
# 7     A good cast and they do their best with what t...
# 8     The only thing that kept me from vomiting afte...
# 9     I just watched this film 15 minutes ago ,  and...
# 10    There are two reasons why I did not give a 1 t...
# 11    The Man In The Attic is a movie set in the 191...
# 12    During a sleepless night ,  I was switching th...
# 13    No , Basically your watching something that do...
# 14    I am dumbfounded that I actually sat and watch...
# 15    In an otherwise good review ,  loleralacartelo...
# 16    This version of Moby Dick insults the audience...
# 17    In a summer that also boasted such repugnant s...
# 18    The dudes at MST3K should see this dog of a fi...
# 19    A mediocre Sci-Fi Channel original picture .  ...
# 20    I went to see this movie with a crowd that con...
# 21    Its hard to make heads or tails of this film ....
# 22    One of those classics ,  held up next to Deep ...
# 23    Joe Don Baker .  He was great in Walking Tall ...
# 24    I waited for this movie to play in great antic...
# 25    Such a long awaited movie .  .  But it has dis...
# 26    five minutes after watching this i logged on t...
# 27    i can't figure out who greenlighted this thing...
# 28    The most ridiculous thing about this ridiculou...
# 29    Seriously ,  I absolutely love these old movie...
# ...                                                 ...
# 9970  Garde  Vue has to be seen a number of times in...
# 9971  Chances are ,  you'll think this movie is incr...
# 9972  Doctor Mordrid is one of those rare films that...
# 9973  Pop quiz :  you're a part of the modern armed ...
# 9974  I found this film to be a fascinating study of...
# 9975  All the folks who sit here and say that this m...
# 9976  There were some great moments of reality in th...
# 9977  The anime that got me hooked on anime .  .  . ...
# 9978  This movie is cold ,  bare truth .  Often we t...
# 9979  Fifteen years later and Paris Is Burning is st...
# 9980  In one of her first movies ,  Romy Schneider s...
# 9981  Cinderella is one of the most beloved of all D...
# 9982  Twelve Monkeys is odd and disturbing ,  yet be...
# 9983  When it comes to movies I can be pretty picky ...
# 9984  It wasn't me !  It was ,  er ,  my twin brothe...
# 9985  I don't hand out ten star ratings easily .  A ...
# 9986  Yes ,  it's over the top ,  yes it's a bit cli...
# 9987  If you have any sort of appreciation for chara...
# 9988  I have seen a lot of Saura films and always fo...
# 9989  Those French and those Germans sure have a lon...
# 9990  please ,  future writers ,  producers ,  direc...
# 9991  Dan Katzir has produced a wonderful film that ...
# 9992  This is perhaps the best rockumentary ever- a ...
# 9993  This is one powerful film .  The first time I ...
# 9994  Myself and my groovadelic 20-something pals ju...
# 9995  Finally ,  an indie film that actually deliver...
# 9996  House of Games is a wonderful movie at multipl...
# 9997  The movie was excellent ,  save for some of th...
# 9998  Spin it ! The 90s opened up with a clever Disn...
# 9999  I keep watching this movie over and over and o...
#
#                                             neg_comment
# 0     Obviously made show famous 1950s stripper Mist...
# 1     This film effective persuading Zionist conspir...
# 2     Unless already familiar pop stars star film , ...
# 3     From around time Europe began fighting World W...
# 4     Im notsurprised even cowgirls get blues movie ...
# 5     ( 48 278 people found comment useful , countin...
# 6     Went watch movie expecting nothing really much...
# 7     A good cast best 're given , story makes sense...
# 8     The thing kept vomiting seeing movie fact acto...
# 9     I watched film 15 minutes ago , I still idea I...
# 10    There two reasons I notgive 1 movie . One reas...
# 11    The Man In The Attic movie set 1910s . It insp...
# 12    During sleepless night , I switching channels ...
# 13    No , Basically watching something notmake sens...
# 14    I dumbfounded I actually sat watched . I love ...
# 15    In otherwise good review , loleralacartelort78...
# 16    This version Moby Dick insults audience claimi...
# 17    In summer also boasted repugnant stinkers Snak...
# 18    The dudes MST3K see dog film . It 's basically...
# 19    A mediocre Sci-Fi Channel original picture . A...
# 20    I went see movie crowd consisted predominantly...
# 21    Its hard make heads tails film . Unless 're we...
# 22    One classics , held next Deep Throat Behind Gr...
# 23    Joe Don Baker . He great Walking Tall good bit...
# 24    I waited movie play great anticipation . Assum...
# 25    Such long awaited movie . . But disappointed f...
# 26    five minutes watching logged IMDb warn notboth...
# 27    ca notfigure greenlighted thing ! redeeming qu...
# 28    The ridiculous thing ridiculous movie conceit ...
# 29    Seriously , I absolutely love old movies simpl...
# ...                                                 ...
# 9970  Garde Vue seen number times order understand s...
# 9971  Chances , 'll think movie incredibly stupid fi...
# 9972  Doctor Mordrid one rare films completely radar...
# 9973  Pop quiz : 're part modern armed forces peacet...
# 9974  I found film fascinating study family crisis ....
# 9975  All folks sit say movie 's weak link Ramones w...
# 9976  There great moments reality depicting modern d...
# 9977  The anime got hooked anime . . . Set year 2010...
# 9978  This movie cold , bare truth . Often think oh ...
# 9979  Fifteen years later Paris Is Burning still afl...
# 9980  In one first movies , Romy Schneider shines yo...
# 9981  Cinderella one beloved Disney classics . And r...
# 9982  Twelve Monkeys odd disturbing , yet clever int...
# 9983  When comes movies I pretty picky , I 'll compl...
# 9984  It not! It , er , twin brother Rupert ! Bobby ...
# 9985  I nothand ten star ratings easily . A movie re...
# 9986  Yes , 's top , yes 's bit clichd yes , Constan...
# 9987  If sort appreciation character dialogue , sens...
# 9988  I seen lot Saura films always found amazing wa...
# 9989  Those French Germans sure long history notliki...
# 9990  please , future writers , producers , director...
# 9991  Dan Katzir produced wonderful film takes us ro...
# 9992  This perhaps best rockumentary ever- British ,...
# 9993  This one powerful film . The first time I saw ...
# 9994  Myself groovadelic 20-something pals ca notget...
# 9995  Finally , indie film actually delivers great s...
# 9996  House Games wonderful movie multiple levels . ...
# 9997  The movie excellent , save scenes Esposito . I...
# 9998  Spin ! The 90s opened clever Disney favorite ,...
# 9999  I keep watching movie . I watch least week . I...
#
# [10000 rows x 6 columns]

# %% [markdown]
# <h1>Classifieur naïf</h1>

# %%
# dumb classification
def dumb_classifier(df, begin, end, step):
    adj_ls = {}

    for i in range(begin, end):
        filtered_tags = df["filtered_tags"][i]

        for e in filtered_tags:
            if not (e in adj_ls.keys()):
                adj_ls[e] = [0, 0]

            if (df["result"][i] == 1):
                j = 0
            else:
                j = 1

            adj_ls[e][j] += 1

    result = {}

    for key, e in adj_ls.items():
        calc = e[0] - e[1]
        if (calc > step or calc < -step):
            result[key] = e

    return result

# %%
def dumb_algo(text):
    result = 0
    
    # if already pre-treated
    if (isinstance(text, list)):
        filtered_tags = text
    else:  
        filtered_tags = pre_traitement(text)
    
    for e in filtered_tags:
        if (not (e in dumb_classified.keys())):
            continue
        
        adj_weight = dumb_classified[e]
        weight = adj_weight[0] - adj_weight[1]
        result += weight

    if (result >= 0):
        return 1
    else:
        return -1

# %% [markdown]
# <h2>Test Dumb classifieur</h2>

# %% [markdown]
# <p>classification</p>

# %%
#exemple dumb classification
size = clean_df.shape[0]
dumb_classified = dumb_classifier(clean_df, 0, size, 5)

dumb_classified
# Out:
# {'famous': [169, 98],
#  'bad': [540, 2936],
#  'little': [1055, 856],
#  'tale': [70, 24],
#  'innocent': [85, 53],
#  'white': [237, 193],
#  'likable': [85, 44],
#  'real': [932, 715],
#  'underwear': [9, 15],
#  'atrocious': [5, 81],
#  'terrible': [96, 628],
#  'notenough': [32, 72],
#  'effective': [112, 38],
#  'possible': [168, 232],
#  'good': [2516, 2212],
#  'familiar': [96, 57],
#  'stop': [33, 39],
#  'next': [283, 272],
#  'Japanese': [172, 87],
#  'teen': [29, 45],
#  'nonsensical': [5, 25],
#  'ready': [48, 57],
#  'endless': [14, 50],
#  'various': [129, 91],
#  'dramatic': [140, 71],
#  'stupid': [92, 541],
#  'spent': [11, 29],
#  'mysterious': [82, 57],
#  'pointless': [5, 65],
#  'piece': [28, 66],
#  'insipid': [3, 28],
#  'mindless': [11, 27],
#  'young': [826, 358],
#  'soldier': [29, 20],
#  'devoid': [3, 24],
#  'best': [1436, 635],
#  'bunch': [38, 119],
#  'musical': [217, 90],
#  'leading': [16, 10],
#  'naive': [42, 33],
#  'meant': [25, 40],
#  'better': [732, 1008],
#  'awful': [46, 568],
#  'incapable': [4, 15],
#  'much': [1067, 882],
#  'hollow': [2, 13],
#  'iconic': [27, 6],
#  'worse': [51, 464],
#  'secret': [80, 61],
#  'least': [361, 685],
#  'talented': [28, 36],
#  'similar': [167, 123],
#  'one-sided': [1, 10],
#  'popular': [122, 64],
#  'well-known': [12, 6],
#  'American': [335, 248],
#  'political': [139, 81],
#  'controversial': [32, 18],
#  'criminal': [51, 27],
#  'intelligent': [82, 44],
#  'rich': [117, 58],
#  'charismatic': [28, 12],
#  'intellectual': [35, 28],
#  'come': [58, 87],
#  'sound': [73, 81],
#  'slow': [135, 167],
#  'brilliant': [237, 55],
#  'solid': [107, 29],
#  'early': [255, 149],
#  'last': [528, 464],
#  'tedious': [9, 59],
#  'full': [290, 224],
#  'earlier': [115, 64],
#  'complete': [136, 250],
#  'dark': [180, 65],
#  'historical': [85, 56],
#  'holy': [3, 10],
#  'fake': [15, 72],
#  'hard': [362, 404],
#  'red': [51, 69],
#  'overall': [163, 80],
#  'total': [59, 160],
#  'want': [97, 225],
#  'start': [38, 46],
#  'clich': [10, 38],
#  'become': [60, 34],
#  'common': [96, 80],
#  'blue': [26, 20],
#  'dead': [166, 235],
#  'clueless': [2, 8],
#  'European': [54, 41],
#  'Sean': [8, 17],
#  'disappointed': [41, 85],
#  'opening': [16, 10],
#  'first': [1018, 815],
#  'logic': [10, 28],
#  'perfect': [316, 78],
#  'sure': [272, 331],
#  'many': [1366, 953],
#  'unintentional': [5, 31],
#  'played': [39, 20],
#  'elaborate': [17, 10],
#  'main': [381, 440],
#  'poor': [155, 541],
#  'realistic': [195, 64],
#  'sister': [21, 15],
#  'local': [167, 155],
#  'apparent': [42, 60],
#  'frankly': [2, 10],
#  'final': [267, 141],
#  'minute': [20, 30],
#  'cool': [85, 102],
#  'different': [517, 296],
#  'else': [26, 42],
#  'useless': [8, 41],
#  'boring': [36, 198],
#  'true': [522, 263],
#  'responsible': [49, 62],
#  'erotic': [44, 29],
#  'live': [211, 105],
#  'jealous': [34, 18],
#  'new': [654, 531],
#  'original': [485, 659],
#  'couple': [93, 76],
#  'embarrassment': [1, 15],
#  'pathetic': [23, 174],
#  'straight': [49, 70],
#  'comic': [173, 113],
#  'cheap': [52, 189],
#  'porn': [11, 59],
#  'father': [41, 23],
#  'must-see': [21, 3],
#  'take': [26, 15],
#  'normal': [101, 58],
#  'everyday': [47, 13],
#  'great': [2341, 761],
#  'notsure': [42, 57],
#  'accomplish': [5, 13],
#  'right': [337, 320],
#  'independent': [67, 52],
#  'whole': [488, 642],
#  'actual': [144, 191],
#  'Such': [38, 32],
#  'exact': [24, 33],
#  'reveal': [11, 5],
#  'incorrect': [3, 10],
#  'available': [107, 42],
#  'entire': [231, 371],
#  'big': [511, 493],
#  'less': [292, 329],
#  'phony': [8, 17],
#  'greatest': [202, 73],
#  'poetic': [32, 5],
#  'obsessive': [13, 4],
#  'wooden': [12, 59],
#  'repugnant': [0, 6],
#  'pretty': [51, 92],
#  'special': [362, 385],
#  'wannabe': [1, 9],
#  'obnoxious': [14, 36],
#  'visual': [141, 63],
#  'atmosphere': [43, 7],
#  'human': [368, 176],
#  'recent': [117, 66],
#  'destroy': [5, 15],
#  'painful': [34, 116],
#  'unbearable': [12, 38],
#  'screen': [143, 127],
#  'unconvincing': [4, 30],
#  'usual': [169, 120],
#  'cast': [48, 41],
#  'bigger': [44, 38],
#  'pile': [3, 38],
#  'dog': [5, 20],
#  'strange': [127, 86],
#  'dumb': [30, 135],
#  'acting': [54, 79],
#  'funny': [551, 511],
#  'stereotypical': [17, 43],
#  'mediocre': [9, 24],
#  'giant': [36, 42],
#  'vague': [10, 27],
#  'frequent': [8, 14],
#  'context': [10, 23],
#  'touch': [50, 27],
#  'physical': [69, 43],
#  'inane': [2, 11],
#  'nonsense': [13, 21],
#  'low': [139, 345],
#  'reasonable': [13, 20],
#  'worst': [73, 963],
#  'grand': [39, 27],
#  'old': [786, 696],
#  'quest': [30, 13],
#  'invisible': [14, 36],
#  'end': [85, 122],
#  'Good': [90, 56],
#  'nature': [25, 17],
#  'decent': [74, 182],
#  'female': [117, 130],
#  'Worth': [18, 2],
#  'deep': [120, 63],
#  'flesh': [20, 33],
#  'obvious': [150, 242],
#  'favorite': [325, 65],
#  'tiny': [46, 30],
#  'child': [41, 27],
#  'light': [97, 63],
#  'understand': [55, 41],
#  'unrealistic': [17, 66],
#  'short': [330, 280],
#  'professional': [56, 37],
#  'save': [17, 51],
#  'initial': [36, 25],
#  'ta': [9, 27],
#  'embarrassed': [2, 28],
#  'biggest': [66, 103],
#  'sorry': [40, 110],
#  'summary': [16, 38],
#  'notbad': [71, 164],
#  'ridiculous': [70, 312],
#  'sick': [58, 103],
#  'fellow': [61, 27],
#  'neurotic': [15, 8],
#  'blonde': [4, 12],
#  'future': [123, 48],
#  'bottom': [19, 41],
#  'notable': [69, 52],
#  'positive': [66, 157],
#  'incompetent': [3, 17],
#  'finest': [91, 14],
#  'middle': [83, 96],
#  'sadistic': [14, 25],
#  'military': [75, 90],
#  'grim': [21, 10],
#  'bloody': [20, 31],
#  'box': [13, 20],
#  'rhyme': [1, 10],
#  'unbelievable': [35, 141],
#  'unoriginal': [4, 32],
#  'non-existent': [3, 47],
#  'classic': [400, 212],
#  'unique': [154, 37],
#  'second': [335, 277],
#  'build': [18, 11],
#  'keep': [22, 30],
#  'scary': [134, 154],
#  'graphic': [48, 36],
#  'emotional': [181, 74],
#  'fair': [47, 56],
#  'one-dimensional': [9, 25],
#  'deepest': [10, 3],
#  'tough': [91, 57],
#  'enjoy': [63, 23],
#  'generic': [8, 27],
#  'thirty': [4, 10],
#  'Special': [10, 17],
#  'notgreat': [49, 38],
#  'evil': [118, 137],
#  'honest': [55, 38],
#  'horror': [30, 52],
#  'prestigious': [10, 4],
#  'predictable': [57, 219],
#  'nasty': [33, 53],
#  'plenty': [73, 38],
#  'dull': [31, 98],
#  'fine': [269, 102],
#  'undead': [4, 10],
#  'top': [255, 149],
#  'laughable': [10, 152],
#  'fun': [95, 65],
#  'rest': [35, 58],
#  'obligatory': [4, 13],
#  'classical': [29, 15],
#  'think': [13, 20],
#  'humble': [29, 19],
#  'interesting': [231, 262],
#  'limited': [33, 21],
#  'asleep': [6, 23],
#  'closer': [43, 24],
#  'happy': [190, 107],
#  'past': [107, 70],
#  'present': [113, 52],
#  'unnecessary': [29, 80],
#  'attempt': [10, 54],
#  'suspense': [33, 25],
#  'black': [287, 240],
#  'long': [299, 283],
#  'hilarious': [262, 123],
#  'struck': [1, 7],
#  'small': [348, 203],
#  'high': [301, 325],
#  'forced': [11, 22],
#  'natural': [124, 33],
#  'choppy': [2, 22],
#  'large': [95, 85],
#  'believable': [158, 58],
#  'subsequent': [37, 9],
#  'ill': [15, 21],
#  'afraid': [28, 48],
#  'excellent': [479, 94],
#  'fat': [14, 46],
#  'Total': [3, 14],
#  'Terrible': [3, 37],
#  'lousy': [9, 72],
#  'lowest': [9, 34],
#  'critical': [36, 22],
#  'oh': [14, 47],
#  'unfunny': [5, 103],
#  'notmuch': [92, 106],
#  'throw': [4, 18],
#  'lead': [104, 98],
#  'sort': [30, 39],
#  'notscary': [6, 32],
#  'sloppy': [15, 28],
#  'neat': [21, 9],
#  'thrown': [20, 28],
#  'Next': [15, 42],
#  'trashy': [11, 24],
#  'trash': [3, 20],
#  'low-budget': [30, 49],
#  'uninspired': [5, 36],
#  'notgood': [75, 147],
#  'English': [86, 55],
#  'gore': [1, 12],
#  'minimal': [13, 20],
#  'single': [126, 233],
#  'girl': [69, 86],
#  'naked': [21, 68],
#  'hot': [85, 101],
#  'entertaining': [96, 52],
#  'successful': [114, 58],
#  'notfunny': [16, 106],
#  'necessary': [75, 38],
#  'worth': [239, 167],
#  'films': [35, 26],
#  'late': [174, 95],
#  'third': [123, 86],
#  'nice': [301, 202],
#  'current': [56, 39],
#  'over-the-top': [32, 24],
#  'mine': [12, 5],
#  'certain': [163, 117],
#  'thought': [27, 33],
#  'gratuitous': [23, 52],
#  'later': [64, 29],
#  'subject': [108, 81],
#  'standard': [33, 46],
#  'imagine': [12, 20],
#  'huge': [149, 176],
#  'due': [188, 121],
#  'horrible': [43, 416],
#  'beautiful': [479, 142],
#  'good-hearted': [9, 1],
#  'Stupid': [0, 20],
#  'utter': [16, 77],
#  'comedic': [65, 38],
#  'nottrue': [6, 20],
#  'foreign': [57, 35],
#  'documentary': [127, 94],
#  'plus': [5, 17],
#  'typical': [135, 101],
#  'arbitrary': [1, 8],
#  'irrelevant': [6, 19],
#  'maximum': [1, 7],
#  'forward': [12, 19],
#  'front': [54, 68],
#  'pretentious': [22, 84],
#  'theater': [3, 13],
#  'central': [77, 35],
#  'legendary': [47, 13],
#  'psychic': [7, 13],
#  'eccentric': [28, 14],
#  'plain': [10, 19],
#  'title': [42, 48],
#  'Many': [91, 63],
#  'incomprehensible': [8, 29],
#  'turgid': [1, 13],
#  'bitten': [0, 14],
#  'bother': [3, 25],
#  'medical': [19, 28],
#  'violent': [78, 54],
#  'suck': [2, 15],
#  'dangerous': [62, 38],
#  'easy': [136, 68],
#  'British': [190, 111],
#  'sci-fi': [67, 46],
#  'forgettable': [7, 33],
#  'lame': [12, 129],
#  'African': [43, 18],
#  'close': [106, 94],
#  'German': [82, 50],
#  'melodramatic': [23, 17],
#  'funniest': [106, 42],
#  'basic': [67, 87],
#  'guess': [14, 32],
#  'shoot': [13, 24],
#  'wrong': [223, 340],
#  'ten': [52, 63],
#  'guns': [0, 6],
#  'notsingle': [15, 26],
#  'unpredictable': [26, 12],
#  'quirky': [26, 13],
#  'hard-boiled': [8, 1],
#  'miscast': [3, 9],
#  'bizarre': [72, 61],
#  'avoid': [26, 56],
#  'crazy': [71, 79],
#  'unneeded': [0, 6],
#  'strong': [268, 93],
#  'quiet': [83, 21],
#  'inept': [7, 44],
#  'superficial': [13, 21],
#  'grade': [3, 17],
#  'simple': [199, 87],
#  'adolescent': [3, 9],
#  'highest': [29, 15],
#  'former': [109, 66],
#  'pregnant': [21, 32],
#  'numerous': [51, 40],
#  'wretched': [3, 10],
#  'travesty': [3, 17],
#  'mean': [37, 48],
#  'trite': [10, 30],
#  'unexplained': [6, 15],
#  'optimistic': [17, 3],
#  'pure': [49, 40],
#  'video': [32, 53],
#  'gray': [6, 12],
#  'guy': [27, 91],
#  'hit-man': [19, 2],
#  'flat': [40, 129],
#  'script': [42, 77],
#  'idiotic': [5, 53],
#  'public': [101, 83],
#  'important': [214, 112],
#  'so-called': [25, 52],
#  'lackluster': [2, 11],
#  'Horrible': [2, 33],
#  'theatrical': [46, 28],
#  'random': [19, 65],
#  'historic': [14, 8],
#  'son': [32, 7],
#  'priest': [9, 16],
#  'suppose': [8, 14],
#  'horrid': [4, 39],
#  'southern': [9, 19],
#  'lose': [33, 18],
#  'able': [244, 164],
#  'spend': [18, 24],
#  'drunk': [8, 18],
#  'enough': [207, 240],
#  'High': [13, 5],
#  'aware': [36, 28],
#  'western': [62, 40],
#  'ill-conceived': [0, 9],
#  'underrated': [60, 6],
#  'Italian': [98, 44],
#  'plot': [26, 48],
#  'green': [26, 46],
#  'outside': [51, 39],
#  'vial': [0, 6],
#  'infected': [2, 12],
#  'zombie': [6, 25],
#  'seek': [11, 20],
#  'particular': [165, 72],
#  'several': [296, 222],
#  'lack': [21, 28],
#  'lot': [53, 35],
#  'open': [97, 110],
#  'unimaginative': [2, 21],
#  'make-up': [14, 23],
#  'rental': [10, 42],
#  'dreadful': [8, 91],
#  'genre': [24, 13],
#  'disgraceful': [0, 9],
#  'silent': [76, 28],
#  'Western': [29, 20],
#  'enjoyable': [208, 75],
#  'silly': [29, 52],
#  'tiresome': [1, 10],
#  'potential': [51, 77],
#  'lucky': [39, 24],
#  'notknow': [10, 21],
#  'believe': [12, 26],
#  'average': [57, 86],
#  'superior': [62, 32],
#  'laugh': [46, 56],
#  'likely': [55, 41],
#  'nonexistent': [1, 10],
#  'artsy': [2, 9],
#  'difficult': [154, 87],
#  'ambitious': [25, 14],
#  'directorial': [26, 17],
#  'novel': [72, 41],
#  'untalented': [0, 10],
#  'lifestyle': [13, 4],
#  'unreal': [9, 18],
#  'disrespectful': [1, 10],
#  'contrary': [18, 24],
#  'incoherent': [2, 30],
#  'supernatural': [32, 17],
#  'discernible': [0, 11],
#  'turd': [1, 9],
#  'mini': [5, 12],
#  'underground': [28, 9],
#  'smaller': [23, 16],
#  'notorious': [22, 14],
#  'amateurish': [4, 68],
#  'unintelligible': [1, 9],
#  'tired': [22, 31],
#  'dysfunctional': [7, 15],
#  'horrendous': [11, 50],
#  'dreary': [6, 19],
#  'unexpected': [62, 15],
#  'ingenious': [15, 7],
#  'redeeming': [0, 31],
#  'write': [38, 62],
#  'unsuspecting': [6, 17],
#  'double': [47, 30],
#  'impossible': [80, 100],
#  'fancy': [6, 19],
#  'website': [7, 13],
#  'private': [47, 21],
#  'personal': [175, 80],
#  'Best': [24, 16],
#  'thin': [26, 61],
#  'routine': [21, 11],
#  'younger': [106, 49],
#  'cultural': [40, 11],
#  'character': [62, 48],
#  'viewer': [107, 60],
#  'notbetter': [16, 8],
#  'native': [36, 30],
#  'Christian': [23, 57],
#  'treacherous': [7, 1],
#  'romantic': [181, 81],
#  'noble': [25, 17],
#  'Native': [9, 18],
#  'ideal': [17, 7],
#  'ignorant': [7, 32],
#  'crappy': [17, 100],
#  'memorable': [167, 46],
#  'Australian': [41, 18],
#  'fail': [7, 14],
#  'give': [138, 164],
#  'make': [35, 65],
#  'credible': [20, 27],
#  'plastic': [5, 18],
#  'stiff': [5, 17],
#  'older': [140, 71],
#  'traditional': [63, 24],
#  'dear': [6, 17],
#  'intense': [86, 21],
#  'tense': [18, 4],
#  'psychological': [63, 35],
#  'objective': [20, 14],
#  'rotten': [6, 14],
#  'higher': [47, 39],
#  'rational': [7, 13],
#  'amazing': [187, 47],
#  'like': [59, 48],
#  'notwrite': [0, 6],
#  'automatic': [3, 11],
#  'male': [67, 57],
#  'depressing': [7, 14],
#  'social': [120, 67],
#  'definitive': [23, 3],
#  'misleading': [3, 11],
#  'sensitive': [49, 16],
#  'worthy': [56, 38],
#  'lower': [26, 51],
#  'essential': [56, 13],
#  'attractive': [47, 56],
#  'magic': [61, 29],
#  'disappointing': [20, 59],
#  'First': [16, 22],
#  'inaccurate': [4, 15],
#  'bible': [6, 20],
#  'angelic': [7, 1],
#  'expensive': [20, 32],
#  'spite': [27, 14],
#  'notice': [17, 9],
#  'die': [12, 18],
#  'masterful': [27, 3],
#  'fantastic': [260, 29],
#  'national': [38, 16],
#  'martial': [61, 50],
#  'absurd': [18, 51],
#  'tragic': [92, 21],
#  'weak': [75, 161],
#  'rebellious': [20, 8],
#  'half': [56, 111],
#  'hidden': [49, 20],
#  'heavy': [59, 51],
#  'thrust': [9, 2],
#  'poorly': [1, 9],
#  'empty': [26, 54],
#  'pitiful': [3, 27],
#  'fit': [37, 28],
#  'faithful': [32, 12],
#  'amateur': [5, 42],
#  'sophomoric': [1, 9],
#  'sweet': [91, 38],
#  'rent': [16, 43],
#  'Much': [55, 35],
#  'powerful': [196, 47],
#  'tight': [33, 11],
#  'vapid': [1, 9],
#  'serial': [64, 56],
#  'internet': [1, 8],
#  'contemporary': [53, 19],
#  'half-baked': [1, 7],
#  'watch': [87, 111],
#  'shallow': [16, 50],
#  'cheese': [7, 18],
#  'execrable': [2, 9],
#  'watchable': [28, 49],
#  'offensive': [14, 57],
#  'bit': [47, 19],
#  'inappropriate': [4, 23],
#  'retarded': [1, 16],
#  'repetitive': [7, 27],
#  'overlong': [3, 9],
#  'boy': [42, 27],
#  'hospital': [21, 12],
#  'creative': [71, 44],
#  'unable': [36, 53],
#  'fresh': [80, 33],
#  'finish': [31, 47],
#  'interminable': [1, 11],
#  'Worse': [5, 16],
#  'cheesy': [20, 31],
#  'ludicrous': [10, 52],
#  'flick': [24, 46],
#  'odd': [72, 53],
#  'sleep': [13, 31],
#  'copy': [17, 10],
#  'welcome': [27, 10],
#  'laughs': [5, 11],
#  'notmiss': [17, 3],
#  'steal': [19, 31],
#  'notrent': [1, 8],
#  'nudity': [1, 10],
#  'rare': [111, 32],
#  'need': [34, 24],
#  'selfish': [12, 23],
#  'unwilling': [14, 3],
#  'angry': [45, 66],
#  'heart-wrenching': [7, 1],
#  'notright': [5, 11],
#  'utterly': [20, 41],
#  'suitable': [18, 10],
#  'wide': [43, 28],
#  'girls': [8, 16],
#  'decide': [6, 19],
#  'know': [101, 87],
#  'unsympathetic': [2, 14],
#  'notworth': [2, 65],
#  'tried': [16, 27],
#  'artistic': [73, 61],
#  'courageous': [9, 2],
#  'insert': [2, 9],
#  'creepy': [43, 36],
#  'key': [52, 38],
#  'Awful': [1, 14],
#  'global': [11, 21],
#  'expert': [22, 8],
#  'lust': [12, 5],
#  'hide': [5, 12],
#  'notworst': [4, 30],
#  'sit': [4, 19],
#  'spectacular': [59, 15],
#  'genuine': [49, 38],
#  'protect': [11, 4],
#  'vicious': [39, 12],
#  'behavior': [13, 7],
#  'permanent': [11, 5],
#  'sub': [2, 8],
#  'impressive': [112, 36],
#  'wasted': [3, 20],
#  'modern': [225, 88],
#  'narrative': [89, 45],
#  'disappear': [4, 10],
#  'ordinary': [54, 18],
#  'unattractive': [8, 19],
#  'fifteen': [13, 19],
#  'no-budget': [0, 7],
#  'French': [156, 49],
#  'unlikely': [36, 27],
#  'involved': [41, 26],
#  'precious': [17, 28],
#  'detective': [45, 28],
#  'nose': [10, 20],
#  'operatic': [9, 1],
#  'interested': [137, 77],
#  'appreciate': [43, 14],
#  'freak': [1, 10],
#  'notpoor': [0, 6],
#  'sympathy': [10, 19],
#  'talentless': [0, 6],
#  'demonic': [9, 19],
#  'satirical': [15, 8],
#  'sinister': [11, 4],
#  'witty': [32, 10],
#  'slapstick': [19, 11],
#  'adventurous': [12, 5],
#  'topless': [4, 16],
#  'surprising': [65, 23],
#  'set-up': [2, 10],
#  'classy': [10, 4],
#  'flimsy': [1, 12],
#  'universal': [13, 5],
#  'promotional': [3, 13],
#  'Scottish': [16, 7],
#  'arm': [1, 7],
#  'greater': [47, 19],
#  'alien': [17, 29],
#  'sappy': [22, 15],
#  'clichd': [2, 18],
#  'material': [29, 20],
#  'dialogue': [11, 17],
#  'unsettling': [11, 4],
#  'prime': [31, 22],
#  'appropriate': [47, 22],
#  'torn': [17, 11],
#  'meaningless': [4, 13],
#  'stupidest': [1, 16],
#  'rural': [32, 4],
#  'moronic': [6, 29],
#  'experimental': [16, 7],
#  'shower': [7, 19],
#  'shot': [120, 149],
#  'bored': [9, 18],
#  'inconsistent': [2, 13],
#  'uncomfortable': [23, 31],
#  'outdated': [1, 7],
#  'lady': [27, 18],
#  'cold': [54, 37],
#  'OK': [10, 54],
#  'dinosaur': [2, 10],
#  'theatre': [5, 19],
#  'gorgeous': [101, 27],
#  'whiny': [4, 12],
#  'admirable': [17, 7],
#  'fill': [5, 19],
#  'uplifting': [17, 4],
#  'fest': [5, 21],
#  'hateful': [3, 14],
#  'clever': [39, 27],
#  'wonderful': [470, 84],
#  'unwatchable': [2, 44],
#  'subtle': [92, 22],
#  'side': [27, 21],
#  'worthless': [1, 13],
#  'autistic': [2, 9],
#  'confused': [18, 35],
#  'colorful': [33, 12],
#  'latter': [45, 34],
#  'flesh-eating': [1, 7],
#  'unpleasant': [10, 28],
#  'unworthy': [0, 6],
#  'inspired': [19, 12],
#  'More': [34, 45],
#  'busy': [21, 15],
#  'minor': [92, 40],
#  'superb': [68, 10],
#  'fabulous': [42, 12],
#  'hole': [10, 16],
#  'miss': [29, 17],
#  'vacuous': [1, 15],
#  'boys': [15, 5],
#  'despicable': [13, 19],
#  'mental': [50, 60],
#  'multiple': [41, 26],
#  'unavailable': [8, 1],
#  'hold': [26, 18],
#  'fight': [36, 42],
#  'shocked': [4, 10],
#  'commentary': [42, 30],
#  'cant': [18, 29],
#  'preposterous': [8, 17],
#  'surreal': [37, 10],
#  'bearable': [1, 8],
#  'experiment': [1, 10],
#  'false': [30, 45],
#  'spare': [9, 18],
#  'sexy': [55, 36],
#  'Asian': [18, 38],
#  'free': [98, 133],
#  'eternal': [19, 4],
#  'ugh': [0, 7],
#  'spoof': [6, 14],
#  'cynical': [30, 21],
#  'overcome': [19, 7],
#  'find': [36, 25],
#  'stick': [21, 59],
#  'self-indulgent': [5, 16],
#  'inner': [28, 18],
#  'perspective': [26, 14],
#  'notfun': [0, 8],
#  'uninspiring': [0, 7],
#  'brutal': [50, 25],
#  'repulsive': [7, 15],
#  'tasteless': [2, 14],
#  'noteasy': [28, 8],
#  'rip-off': [1, 8],
#  'slasher': [8, 21],
#  'mechanical': [24, 14],
#  'animated': [39, 10],
#  'elementary': [2, 11],
#  'technical': [64, 55],
#  'extra': [58, 43],
#  'vibrant': [18, 3],
#  'international': [40, 30],
#  'vulnerable': [28, 7],
#  'dribble': [0, 8],
#  'sleazy': [24, 11],
#  'notstupid': [2, 9],
#  'loser': [4, 18],
#  'monster': [4, 13],
#  'Korean': [10, 20],
#  'survive': [49, 19],
#  'cover': [6, 15],
#  'text': [7, 14],
#  'portray': [17, 10],
#  'ashamed': [1, 12],
#  'Rican': [0, 8],
#  'let': [8, 14],
#  'beauty': [9, 2],
#  'satisfying': [14, 2],
#  'supposed': [1, 22],
#  'cheapest': [2, 8],
#  'aspect': [26, 20],
#  'follow': [44, 36],
#  'mixed': [40, 26],
#  'opposite': [41, 31],
#  'lazy': [9, 25],
#  'bite': [1, 8],
#  'suspenseful': [46, 15],
#  'actress': [34, 24],
#  'okay': [7, 15],
#  'sat': [3, 13],
#  'crowd': [10, 3],
#  'vocal': [16, 7],
#  'latest': [41, 31],
#  'lovable': [33, 13],
#  'regular': [57, 31],
#  'smile': [36, 13],
#  'abysmal': [2, 38],
#  'lesbian': [13, 43],
#  'tremendous': [40, 9],
#  'unrelated': [8, 15],
#  'art': [28, 19],
#  'semi': [1, 7],
#  'handsome': [34, 9],
#  'blank': [4, 16],
#  'impressed': [27, 17],
#  'fond': [13, 3],
#  'moral': [70, 51],
#  'desperate': [41, 47],
#  'suburban': [12, 4],
#  'loyal': [26, 11],
#  'constructive': [0, 6],
#  'comment': [5, 13],
#  'digital': [20, 26],
#  'magical': [64, 15],
#  'lyrical': [11, 2],
#  'aristocratic': [8, 1],
#  'lovely': [25, 10],
#  'illogical': [6, 29],
#  'fan': [35, 46],
#  'cop': [6, 12],
#  'dimensional': [5, 18],
#  '20th': [37, 6],
#  'sympathetic': [52, 21],
#  'Sebastian': [2, 19],
#  'laughter': [10, 17],
#  'fourth': [30, 15],
#  'read': [46, 77],
#  'Irish': [25, 15],
#  'expected': [0, 8],
#  'guest': [17, 4],
#  'intriguing': [24, 10],
#  'waste': [0, 13],
#  'surprised': [49, 32],
#  'overwhelming': [17, 8],
#  'humorous': [60, 39],
#  'on-screen': [25, 10],
#  'upper': [20, 14],
#  'handy': [9, 1],
#  'tear': [17, 7],
#  'intact': [7, 15],
#  'fifty': [14, 7],
#  'Incredible': [3, 11],
#  'rubbish': [17, 64],
#  'clue': [3, 11],
#  'dad': [15, 9],
#  'alone': [11, 21],
#  'birth': [10, 2],
#  'clean': [44, 26],
#  'domestic': [20, 9],
#  'economic': [13, 5],
#  'return': [9, 3],
#  'super': [30, 48],
#  'rival': [28, 6],
#  'naughty': [2, 12],
#  'wild': [70, 27],
#  'drive': [12, 22],
#  'sentimental': [42, 17],
#  'storyline': [26, 34],
#  'earth': [8, 29],
#  'enjoyed': [21, 9],
#  'married': [35, 21],
#  'incredible': [163, 40],
#  'Indian': [72, 61],
#  'song': [35, 16],
#  'notmany': [34, 20],
#  'misogynistic': [1, 7],
#  'hit': [20, 11],
#  'sophisticated': [32, 6],
#  'prominent': [11, 3],
#  'unknown': [62, 46],
#  'humour': [21, 10],
#  'dire': [3, 18],
#  'love': [101, 37],
#  'self-respecting': [0, 6],
#  'stark': [14, 3],
#  'immortal': [14, 5],
#  'element': [16, 8],
#  'exotic': [19, 11],
#  'mess': [4, 18],
#  'grainy': [6, 13],
#  'wan': [2, 8],
#  'liked': [29, 15],
#  'self-centered': [3, 9],
#  'witless': [0, 9],
#  'turkey': [0, 13],
#  'face': [9, 2],
#  'outstanding': [126, 25],
#  'stellar': [27, 7],
#  'youthful': [12, 4],
#  'bear': [6, 15],
#  'urge': [2, 12],
#  'quick': [40, 49],
#  'tacky': [8, 23],
#  'hideous': [11, 38],
#  'comfortable': [24, 11],
#  'god': [6, 30],
#  'immediate': [17, 9],
#  'rid': [24, 16],
#  'adult': [17, 6],
#  'bitter': [27, 11],
#  'black-and-white': [9, 3],
#  'notafraid': [17, 7],
#  'substantial': [11, 5],
#  'careful': [17, 10],
#  'token': [5, 12],
#  'constant': [58, 45],
#  'facial': [44, 27],
#  'self-absorbed': [4, 10],
#  'u': [25, 34],
#  'notbig': [34, 16],
#  'unforgettable': [56, 7],
#  'well-made': [14, 5],
#  'mutual': [17, 8],
#  'unnatural': [1, 17],
#  'tribal': [10, 2],
#  'miserable': [13, 25],
#  'insult': [2, 21],
#  'portrayal': [39, 16],
#  'magnificent': [48, 9],
#  'shaky': [7, 20],
#  'cerebral': [14, 4],
#  'fantasy': [70, 17],
#  'call': [9, 22],
#  'Romanian': [0, 8],
#  'closest': [21, 12],
#  'ultimate': [60, 23],
#  'hybrid': [5, 11],
#  'notbest': [34, 11],
#  'organic': [1, 8],
#  'fairy': [19, 10],
#  'universe': [29, 13],
#  'ironic': [27, 17],
#  'hear': [73, 29],
#  'Several': [24, 10],
#  'implausible': [9, 19],
#  'lighter': [11, 1],
#  'blatant': [4, 15],
#  'annoying': [2, 9],
#  'authentic': [39, 13],
#  'Happy': [6, 17],
#  'sub-plots': [1, 7],
#  'widescreen': [16, 4],
#  'pull': [14, 20],
#  'mild': [9, 16],
#  'putrid': [2, 12],
#  'off-screen': [0, 9],
#  'tolerable': [3, 11],
#  ...}

# %% [markdown]
# <p>Tester le résultat sur un commentaire positif et négatif du jeu de données initiale</p>

# %%
text1 = clean_df["comment"][4]
result1 = apply_algo(dumb_algo, dumb_sarcasme, text1)

text2 = clean_df["comment"][5285]
result2 = apply_algo(dumb_algo, dumb_sarcasme, text2)

text_neg = "this is not good"
result3 = apply_algo(dumb_algo, dumb_sarcasme, text_neg)

print(result1, result2, result3)
# Out:
# -1 1 -1

# %% [markdown]
# <p>Evaluer le taux de réussiste sur le jeu de données initiale</p>

# %%
dumb_coef = test_algo(dumb_algo, dumb_sarcasme, clean_df)

print('accuracy du jeu de données initial:\n')
print(dumb_coef["accuracy"])
print ('\n matrice de confusion \n',dumb_coef["confusion"])
print(dumb_coef["report"])
# Out:
# accuracy du jeu de données initial:
#
# 0.7638
#
#  matrice de confusion
#  [[3168 1832]
#  [ 530 4470]]
#               precision    recall  f1-score   support
#
#           -1       0.86      0.63      0.73      5000
#            1       0.71      0.89      0.79      5000
#
#    micro avg       0.76      0.76      0.76     10000
#    macro avg       0.78      0.76      0.76     10000
# weighted avg       0.78      0.76      0.76     10000

# %% [markdown]
# <h1>classifieurs SickitLearn</h1>

# %%
def classification(clf, x, y, min_df = 0.0015, max_df=0.3, ngram_range=(1,3), is_to_array=False):
    vectorizer = TfidfVectorizer(min_df = min_df, max_df=max_df, ngram_range=ngram_range)
    k_fold = KFold(n_splits=10, random_state=None, shuffle=True)
    x = vectorizer.fit_transform(x)
    
    if is_to_array: x = x.toarray()
    
    clf.fit(x, y)
    
    r = {"clf": clf, "k_fold": k_fold, "vectorizer": vectorizer, "x": x}
    
    return r

# %%
def scoring_classification(clf, k_fold, x, y):
    score = cross_val_score(clf, x, y, cv=k_fold, scoring='accuracy')

    print('Les différentes accuracy pour les 10 évaluations sont :')
    print(score)
    print ('Accuracy moyenne :', score.mean())
    print('standard deviation', score.std())

# %% [markdown]
# <h2>MultinomialNB</h2>

# %%
r = classification(
    MultinomialNB(),
    clean_df["clean_comment"],
    clean_df["result"]
)

clf_multi_nb = r["clf"]
k_fold = r["k_fold"]
vectorizer_multi_nb = r["vectorizer"]

scoring_classification(
    clf_multi_nb,
    k_fold,
    r["x"],
    clean_df["result"]
)
# Out:
# Les différentes accuracy pour les 10 évaluations sont :
# [0.917 0.901 0.911 0.908 0.902 0.903 0.92  0.903 0.919 0.905]
# Accuracy moyenne : 0.9089
# standard deviation 0.00700642562224135

# %% [markdown]
# <h2>GaussianNB</h2>

# %%
r = classification(
    GaussianNB(),
    clean_df["clean_comment"],
    clean_df["result"],
    ngram_range=(1,3),
    is_to_array=True
)

clf_gaussian = r["clf"]
k_fold = r["k_fold"]
vectorizer_gaussian = r["vectorizer"]

scoring_classification(
    clf_gaussian,
    k_fold,
    r["x"],
    clean_df["result"]
)
# Out:
# Les différentes accuracy pour les 10 évaluations sont :
# [0.859 0.865 0.88  0.882 0.883 0.88  0.887 0.877 0.884 0.876]
# Accuracy moyenne : 0.8773
# standard deviation 0.008343260753446468

# %% [markdown]
# <h2>DecisionTreeClassifier</h2>

# %%
r = classification(
    DecisionTreeClassifier(random_state=0),
    clean_df["text_filtered_tags"],
    clean_df["result"],
    ngram_range=(1,2)
)

clf_tree = r["clf"]
k_fold = r["k_fold"]
vectorizer_tree = r["vectorizer"]

scoring_classification(
    clf_tree,
    k_fold,
    r["x"],
    clean_df["result"]
)
# Out:
# Les différentes accuracy pour les 10 évaluations sont :
# [0.75  0.762 0.761 0.719 0.733 0.742 0.739 0.735 0.733 0.763]
# Accuracy moyenne : 0.7436999999999999
# standard deviation 0.014092906016858283

# %% [markdown]
# <h1>Test des différents classifieur</h1>

# %% [markdown]
# <h2>Tester sur un jeu de données indépendant</h2>
# <p>Pour vérifier si un classifieur est efficace, il faut avoir une estimation moyenne des bons et des mauvais résultats qu'il donne. Cependant, faire cette moyenne sur le jeu de données sur lequel on a apprit, peut s'avérer faux. En effet, il se peut que la classification colle trop au jeu de données. Dans ce cas, si on fait le test sur un autre jeu de données, les résultats pourront être mauvais. Il est donc important d'avoir un autre jeu de données, sur lequel on ne fait aucune classification pour avoir un taux de réussite "réaliste".</p>

# %%
df_test = pd.read_csv('../data/test.csv',sep="\t", header=None, encoding="utf8")
del df_test[0]
df_test = df_test.rename(index = int, columns = {1: "comment", 2: "result"})

clean_df_test = parse_df(df_test)

# %% [markdown]
# <h3>Test de Dumb Classifier</h3>

# %%
dumb_coef_test = test_algo(dumb_algo, dumb_sarcasme, clean_df_test)

print('accuracy du jeu de données de IMDB:\n')
print(dumb_coef_test["accuracy"])
print ('\n matrice de confusion \n',dumb_coef_test["confusion"])
print(dumb_coef_test["report"])
# Out:
# accuracy du jeu de données de IMDB:
#
# 0.71842
#
#  matrice de confusion
#  [[13733 11267]
#  [ 2812 22188]]
#               precision    recall  f1-score   support
#
#           -1       0.83      0.55      0.66     25000
#            1       0.66      0.89      0.76     25000
#
#    micro avg       0.72      0.72      0.72     50000
#    macro avg       0.75      0.72      0.71     50000
# weighted avg       0.75      0.72      0.71     50000

# %% [markdown]
# <h2>Jeu de données du challenge</h2>

# %%
df_challenge_comment = pd.read_csv('../data/challenge/test_data.csv',sep="\t", header=None, encoding="utf8")
df_challenge_comment = df_challenge_comment.rename(index = int, columns = {0: "comment"})

df_challenge_result = pd.read_csv('../data/challenge/test_labels.csv',sep="\t", header=None, encoding="utf8")
df_challenge_result = df_challenge_result.rename(index = int, columns = {0: "result"})

df_challenge_raw = pd.concat([df_challenge_comment, df_challenge_result], axis=1)
df_challenge_clean = parse_df(df_challenge_raw)

# %% [markdown]
# <h3>Test de Dumb classifier</h3>

# %%
dumb_coef_test = test_algo(dumb_algo, dumb_sarcasme, df_challenge_clean)

print('accuracy du jeu de données du challenge:\n')
print(dumb_coef_test["accuracy"])
print ('\n matrice de confusion \n',dumb_coef_test["confusion"])
print(dumb_coef_test["report"])
# Out:
# accuracy du jeu de données du challenge:
#
# 0.7765
#
#  matrice de confusion
#  [[1308  692]
#  [ 202 1798]]
#               precision    recall  f1-score   support
#
#           -1       0.87      0.65      0.75      2000
#            1       0.72      0.90      0.80      2000
#
#    micro avg       0.78      0.78      0.78      4000
#    macro avg       0.79      0.78      0.77      4000
# weighted avg       0.79      0.78      0.77      4000

# %% [markdown]
# <h2>Pipeline</h2>

# %% [markdown]
# <p>Test de MultinomialNB sur :</p>
# <ul>
#     <li>jeu de données d'entraînement</li>
#     <li>jeu de données IMDB</li>
#     <li>jeu de données challenge</li>
# </ul>

# %%
def display_result(result, y):
    accuracy = accuracy_score(y, result)
    report = classification_report(y, result)
    confusion = confusion_matrix(y, result)
    
    print(accuracy)
    print ('\n matrice de confusion \n',confusion)
    print(report)

# %%
pipeline = Pipeline([
    ('vect', TfidfVectorizer(min_df = 0.0015, max_df=0.3, ngram_range=(1,3))),
    ('trans', TfidfTransformer()),
    ('clf', MultinomialNB())
])

pipeline.fit(clean_df["clean_comment"], clean_df["result"])

pred1 = pipeline.predict(clean_df["clean_comment"])
pred2 = pipeline.predict(clean_df_test["clean_comment"])
pred3 = pipeline.predict(df_challenge_clean["clean_comment"])

print("résulat jeu de données d'entraînement :")
print(display_result(pred1, clean_df["result"]))

print ("--------------------------------------------------")

print("résulat jeu de données IMDB :")
print(display_result(pred2, clean_df_test["result"]))

print ("--------------------------------------------------")

print("résulat jeu de données challenge :")
print(display_result(pred3, df_challenge_clean["result"]))
# Out:
# résulat jeu de données d'entraînement :
# 0.9515
#
#  matrice de confusion
#  [[4730  270]
#  [ 215 4785]]
#               precision    recall  f1-score   support
#
#           -1       0.96      0.95      0.95      5000
#            1       0.95      0.96      0.95      5000
#
#    micro avg       0.95      0.95      0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# None
# --------------------------------------------------
# résulat jeu de données IMDB :
# 0.86502
#
#  matrice de confusion
#  [[20475  4525]
#  [ 2224 22776]]
#               precision    recall  f1-score   support
#
#           -1       0.90      0.82      0.86     25000
#            1       0.83      0.91      0.87     25000
#
#    micro avg       0.87      0.87      0.87     50000
#    macro avg       0.87      0.87      0.86     50000
# weighted avg       0.87      0.87      0.86     50000
#
# None
# --------------------------------------------------
# résulat jeu de données challenge :
# 0.91675
#
#  matrice de confusion
#  [[1808  192]
#  [ 141 1859]]
#               precision    recall  f1-score   support
#
#           -1       0.93      0.90      0.92      2000
#            1       0.91      0.93      0.92      2000
#
#    micro avg       0.92      0.92      0.92      4000
#    macro avg       0.92      0.92      0.92      4000
# weighted avg       0.92      0.92      0.92      4000
#
# None

# %% [markdown]
# <p>Sauvegarde du modèle</p>

# %%
#filename = "../z.pkl"
#pickle.dump(pipeline, open(filename, "wb"))
